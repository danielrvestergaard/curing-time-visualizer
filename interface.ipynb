# %%
from concrete import Concrete2023
from curing_time_visualizer import CuringTimeVisualizer

# %%
viz = CuringTimeVisualizer(Concrete2023)
viz.display()
# Out:
# interactive(children=(Dropdown(description='Strength class:', index=4, options=('C12/15', 'C16/20', 'C20/25', …
